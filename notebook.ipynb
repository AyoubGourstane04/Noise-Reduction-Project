# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import soundfile as sf
import scipy.fftpack as fft
from scipy.signal import medfilt

# %%
y, sr = librosa.load('/home/ayoub/sound.wav', sr=None)

S_full, phase = librosa.magphase(librosa.stft(y))

noise_power = np.mean(S_full[:, :int(sr*0.1)], axis=1)

mask = S_full > noise_power[:, None]
mask = mask.astype(float)

mask = medfilt(mask, kernel_size=(1,5))

S_clean = S_full*mask

y_clean = librosa.istft(S_clean * phase)

sf.write('/home/ayoub/clean.wav', y_clean, sr)
# Out:
# /tmp/ipykernel_101122/1771579808.py:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load('/home/ayoub/sound.wav', sr=None)
# /home/ayoub/miniconda3/envs/noise-proj-env/lib/python3.10/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
